# %%
#Assignment 1: Temperature Check
Problem:
Write a program that takes the current temperature as input and prints:
● "It's too cold!" if below 10°C
● "It's cool outside" if between 10°C and 25°C
● "It's hot outside!" if above 25°C

# %%
# Get temperature input from user
temp = float(input("Enter the current temperature in °C: "))

# Check temperature conditions and print appropriate message
if temp < 10:
    print("It's too cold!")
elif temp <= 25:
    print("It's cool outside")
else:
    print("It's hot outside!")
# Out:
# Enter the current temperature in °C: 9
# It's too cold!

# %%
#Assignment 2: ATM Withdrawal System
Problem:
Ask the user for their account balance and the amount they want to withdraw.
● If the withdrawal amount is greater than the balance → print "Insufficient
Balance"
● If the withdrawal amount is less than or equal to balance → print "Transaction
Successful" and show the remaining balance.

# %%
# Get user inputs and convert to numbers
account_balance = float(input("Enter your account balance: $"))
withdrawal_amount = float(input("Enter the amount to withdraw: $"))

# Check if withdrawal is possible
if withdrawal_amount > account_balance:
    print("Insufficient Balance")
else:
    remaining_balance = account_balance - withdrawal_amount
    print("Transaction Successful")
    print(f"Remaining balance: ${remaining_balance:.2f}")

# %%
#Assignment 3: Student Grade Calculator
Problem:
Input marks (0–100) and print grade based on:
● 90–100 → A+
● 80–89 → A
● 70–79 → B
● 60–69 → C
● Below 60 → Fail

# %%
# Get marks from user
marks = float(input("Enter your marks (0-100): "))

# Determine grade based on marks
if marks >= 90:
    print("A+")
elif marks >= 80:
    print("A")
elif marks >= 70:
    print("B")
elif marks >= 60:
    print("C")
else:
    print("Fail")

# %%
#Assignment 4: Bus Ticket Discount
Problem:
Ask the user for age and print ticket price:
● Below 5 → Free
● 5–18 → 50% Discount
● 60 or above → 30% Discount
● Others → Full Price

# %%
# Get age from user
age = int(input("Enter your age: "))

# Determine ticket price based on age
if age < 5:
    print("Free")
elif age <= 18:
    print("50% Discount")
elif age >= 60:
    print("30% Discount")
else:
    print("Full Price")
# Out:
# Enter your age: 12
# 50% Discount

# %%
#Assignment 5: Restaurant Bill with Discount
Problem:
Take total bill amount from the user:
● If the bill is above 1000 → apply 10% discount
● Otherwise → no discount
Then print the final bill amount.

# %%
# Get bill amount from user
bill = float(input("Enter the total bill amount: $"))

# Apply discount if bill is above 1000
if bill > 1000:
    final_bill = bill * 0.9  # 10% discount
    print(f"Discount applied: 10%")
    print(f"Final bill amount: ${final_bill:.2f}")
else:
    print(f"No discount applied")
    print(f"Final bill amount: ${bill:.2f}")
# Out:
# Enter the total bill amount: $45
# No discount applied
# Final bill amount: $45.00

# %%
#Assignment 6: Login Authentication
Problem:
Take a username and password input.
● If username == "admin" and password == "12345" → print "Login Successful"
● Else → print "Invalid Credentials"

# %%
# Get username and password from user
username = input("Enter username: ")
password = input("Enter password: ")

# Check credentials
if username == "admin" and password == "12345":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: rana
# Enter password: 123456
# Invalid Credentials

# %%
#Assignment 7: Traffic Light System
Problem:
Ask the user to input a color (red, yellow, or green).
Print:
● "Stop" for red
● "Ready to go" for yellow
● "Go" for green
● "Invalid color" otherwise

# %%
# Get color input from user
color = input("Enter traffic light color (red/yellow/green): ").lower().strip()

# Determine action based on color
if color == "red":
    print("Stop")
elif color == "yellow":
    print("Ready to go")
elif color == "green":
    print("Go")
else:
    print("Invalid color")
# Out:
# Enter traffic light color (red/yellow/green): red
# Stop

# %%
#Assignment 8: Leap Year Checker
Problem:
Take a year as input and check:
● If it is divisible by 400 → Leap Year
● Else if divisible by 4 but not by 100 → Leap Year
● Otherwise → Not a Leap Year

# %%
# Get year from user
year = int(input("Enter a year: "))

# Check leap year conditions in order
if year % 400 == 0:
    print("Leap Year")
elif year % 4 == 0 and year % 100 != 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 509
# Not a Leap Year

# %%
#Assignment 9: Job Eligibility Checker
Problem:
Input age and qualification.
● If age > 18 and qualification is “graduate” → print "Eligible for Job"
● Else → "Not Eligible"

# %%
# Get age and qualification from user
age = int(input("Enter your age: "))
qualification = input("Enter your qualification: ").lower().strip()

# Check eligibility criteria
if age >= 18 and qualification == "graduate":
    print("Eligible for Job")
else:
    print("Not Eligible")
# Out:
# Enter your age: 345
# Enter your qualification: none
# Not Eligible

# %%
#Assignment 10: Electricity Bill Calculator
Problem:
Input number of units consumed and calculate bill:
● Up to 100 units → 5 BDT per unit
● 101–200 units → 7 BDT per unit
● Above 200 units → 10 BDT per unit
Print total payable amount.

# %%
# Get units consumed from user
units = float(input("Enter number of units consumed: "))

# Calculate bill based on tiered pricing structure
if units < 100:
    bill = units * 5
elif units <= 200:
    # First 100 units at 5 BDT, remaining at 7 BDT
    bill = (100 * 5) + ((units - 100) * 7)
else:
    # First 100 at 5 BDT, next 100 at 7 BDT, remaining at 10 BDT
    bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

print(f"Total payable amount: {bill:.2f} BDT")
# Out:
# Enter number of units consumed: 34
# Total payable amount: 170.00 BDT
